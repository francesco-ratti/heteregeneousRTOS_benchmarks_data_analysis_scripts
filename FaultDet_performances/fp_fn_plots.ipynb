# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

# %%
ln_df=pd.read_csv("latnav_2_synth.csv", delimiter=";")

# %%
ln_df.head()
# Out:
#    Unnamed: 0  Benchmark  regions  trainingIterations  testIterations  \
# 0           0        NaN     16.0               800.0         50000.0
# 1           1        NaN     16.0              1600.0         50000.0
# 2           2        NaN     16.0              3200.0         50000.0
# 3           3        NaN     16.0              6400.0         50000.0
# 4           4        NaN     16.0             12800.0         50000.0
#
#    totalPos    totalNeg  fp_rate    fn_rate  fn_percerr_mean  ...  \
# 0   50000.0  25802840.0   16.340  55.099032         1.190994  ...
# 1   50000.0  28029479.0    9.274  56.697807         1.894934  ...
# 2   50000.0  29407987.0    4.906  58.023523         2.769751  ...
# 3   50000.0  30262430.0    2.198  58.855327         3.578548  ...
# 4   50000.0  30665260.0    0.904  59.764656         4.792979  ...
#
#    fn_percerr_2.5percentile  fn_percerr_10percentile  \
# 0                  0.000011                 0.000011
# 1                  0.000011                 0.000011
# 2                  0.000011                 0.000011
# 3                  0.000011                 0.000011
# 4                  0.000011                 0.000011
#
#    fn_percerr_firstquartile  fn_percerr_median  fn_percerr_thirdquartile  \
# 0                  0.000078           0.000713                  0.032375
# 1                  0.000078           0.000828                  0.034706
# 2                  0.000079           0.001139                  0.036163
# 3                  0.000081           0.001375                  0.036751
# 4                  0.000088           0.001437                  0.037335
#
#    fn_percerr_90percentile  fn_percerr_97.5percentile  \
# 0                 0.125168                   8.007048
# 1                 0.205612                  22.160403
# 2                 0.500511                  32.042584
# 3                 0.551264                  53.798330
# 4                 0.738112                  85.103375
#
#    fn_percerr_99percentile  fn_percerr_min  fn_percerr_max
# 0                32.042959        0.000006      299.773502
# 1                75.935048        0.000006      300.000000
# 2                89.093620        0.000006      300.000000
# 3               110.353904        0.000006     1151.853466
# 4               112.096846        0.000006     1199.188137
#
# [5 rows x 22 columns]

# %%
ln_df.dropna(axis=1, inplace=True)

# %%
ln_df.drop(ln_df[ln_df['regions'] != 16 ].index, inplace=True)

# %%
ln_df.head()
# Out:
#    Unnamed: 0  regions  trainingIterations  testIterations  totalPos  \
# 0           0     16.0               800.0         50000.0   50000.0
# 1           1     16.0              1600.0         50000.0   50000.0
# 2           2     16.0              3200.0         50000.0   50000.0
# 3           3     16.0              6400.0         50000.0   50000.0
# 4           4     16.0             12800.0         50000.0   50000.0
#
#      totalNeg  fp_rate    fn_rate  fn_percerr_mean  fn_relerr_var  ...  \
# 0  25802840.0   16.340  55.099032         1.190994       0.009474  ...
# 1  28029479.0    9.274  56.697807         1.894934       0.016518  ...
# 2  29407987.0    4.906  58.023523         2.769751       0.025020  ...
# 3  30262430.0    2.198  58.855327         3.578548       0.037505  ...
# 4  30665260.0    0.904  59.764656         4.792979       0.056315  ...
#
#    fn_percerr_2.5percentile  fn_percerr_10percentile  \
# 0                  0.000011                 0.000011
# 1                  0.000011                 0.000011
# 2                  0.000011                 0.000011
# 3                  0.000011                 0.000011
# 4                  0.000011                 0.000011
#
#    fn_percerr_firstquartile  fn_percerr_median  fn_percerr_thirdquartile  \
# 0                  0.000078           0.000713                  0.032375
# 1                  0.000078           0.000828                  0.034706
# 2                  0.000079           0.001139                  0.036163
# 3                  0.000081           0.001375                  0.036751
# 4                  0.000088           0.001437                  0.037335
#
#    fn_percerr_90percentile  fn_percerr_97.5percentile  \
# 0                 0.125168                   8.007048
# 1                 0.205612                  22.160403
# 2                 0.500511                  32.042584
# 3                 0.551264                  53.798330
# 4                 0.738112                  85.103375
#
#    fn_percerr_99percentile  fn_percerr_min  fn_percerr_max
# 0                32.042959        0.000006      299.773502
# 1                75.935048        0.000006      300.000000
# 2                89.093620        0.000006      300.000000
# 3               110.353904        0.000006     1151.853466
# 4               112.096846        0.000006     1199.188137
#
# [5 rows x 21 columns]

# %%
ann_df=pd.read_csv("ann_synth.csv", delimiter=";")

# %%
ann_df.dropna(axis=1, inplace=True)

# %%
ann_df['regions'].value_counts()
# Out:
# regions
# 16.0    9
# Name: count, dtype: int64

# %%
fft_df=pd.read_csv("fft_8_synth.csv", delimiter=";")

# %%
fft_df.dropna(axis=1, inplace=True)

# %%
fft_df['regions'].value_counts()
# Out:
# regions
# 16.0    7
# Name: count, dtype: int64

# %%
gauss_df=pd.read_csv("gauss_synth.csv", delimiter=";")

# %%
gauss_df.dropna(axis=1, inplace=True)

# %%
gauss_df['regions'].value_counts()
# Out:
# regions
# 16.0    7
# Name: count, dtype: int64

# %%
fig = plt.plot(np.log2((ln_df["trainingIterations"]/100)).astype(int), ln_df["fp_rate"],marker="o", label='Latnav')
plt.plot(np.log2((ann_df["trainingIterations"]/100)).astype(int), ann_df["fp_rate"],marker="o", label="ANN")
plt.plot(np.log2((gauss_df["trainingIterations"]/100)).astype(int), gauss_df["fp_rate"],marker="o", label="Gaussian blur")
plt.plot(np.log2((fft_df["trainingIterations"]/100)).astype(int), fft_df["fp_rate"],marker="o", label="FFT")

        
plt.grid(visible=True, which='major', color='0.6')
plt.grid(visible=True, which='minor', color='0.8')
plt.yscale('log')
ax = plt.gca()
#ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(4))
ax.tick_params(axis='y', which='minor', bottom=False)
#plt.gcf().subplots_adjust(left=0.2)
ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x,pos: ('{:d}'.format(int(pow(2, x))*100))))
    
#plt.style.use('classic')
#region_2d_trainIterations=np.array(region_trainIterations)
#region_2d_fp_rate=np.array(region_fp_rate)
#ax.set_ylim([pow(10, math.floor(math.log10(np.min(region_2d_fp_rate)))), pow(10, math.ceil(math.log10(np.max(region_2d_fp_rate))))])
        
#ax.yaxis.set_major_formatter(tkr.PercentFormatter(decimals=2))




plt.xlabel("Training iterations")
plt.ylabel("False positives rate [%]")
plt.legend()

# %%
fig = plt.plot(np.log2((ln_df["trainingIterations"]/100)).astype(int), ln_df["fn_rate"],marker="o", label='Latnav')
plt.plot(np.log2((ann_df["trainingIterations"]/100)).astype(int), ann_df["fn_rate"],marker="o", label="ANN")
plt.plot(np.log2((gauss_df["trainingIterations"]/100)).astype(int), gauss_df["fn_rate"],marker="o", label="Gaussian blur")
plt.plot(np.log2((fft_df["trainingIterations"]/100)).astype(int), fft_df["fn_rate"],marker="o", label="FFT")

plt.grid(visible=True, which='major', color='0.6')
plt.grid(visible=True, which='minor', color='0.8')
#plt.yscale('log')
ax = plt.gca()
#plt.style.use('classic')
#region_2d_trainIterations=np.array(region_trainIterations)
#region_2d_fp_rate=np.array(region_fp_rate)
#ax.set_ylim([pow(10, math.floor(math.log10(np.min(region_2d_fp_rate)))), pow(10, math.ceil(math.log10(np.max(region_2d_fp_rate))))])
ax.yaxis.set_major_formatter(tkr.PercentFormatter(decimals=0))

#ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(4))
ax.tick_params(axis='y', which='minor', bottom=False)
#plt.gcf().subplots_adjust(left=0.2)
ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x,pos: ('{:d}'.format(int(pow(2, x))*100))))
        

plt.xlabel("Training iterations")
plt.ylabel("Bit-true false negatives rate [%]")
plt.legend()

# %%
ln_df.drop(ln_df[ln_df['trainingIterations'] > 51200 ].index, inplace=True)

# %%
ann_df.drop(ann_df[ann_df['trainingIterations'] > 51200 ].index, inplace=True)

# %%
fig = plt.plot(np.log2((ln_df["trainingIterations"]/100)).astype(int), ln_df["fp_rate"],marker="o", label='Latnav')
plt.plot(np.log2((ann_df["trainingIterations"]/100)).astype(int), ann_df["fp_rate"],marker="o", label="ANN")
plt.plot(np.log2((gauss_df["trainingIterations"]/100)).astype(int), gauss_df["fp_rate"],marker="o", label="Gaussian blur")
plt.plot(np.log2((fft_df["trainingIterations"]/100)).astype(int), fft_df["fp_rate"],marker="o", label="FFT")

        
plt.grid(visible=True, which='major', color='0.6')
plt.grid(visible=True, which='minor', color='0.8')
plt.yscale('log')
ax = plt.gca()
#ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(4))
ax.tick_params(axis='y', which='minor', bottom=False)
#plt.gcf().subplots_adjust(left=0.2)
ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x,pos: ('{:d}'.format(int(pow(2, x))*100))))
    
#plt.style.use('classic')
#region_2d_trainIterations=np.array(region_trainIterations)
#region_2d_fp_rate=np.array(region_fp_rate)
#ax.set_ylim([pow(10, math.floor(math.log10(np.min(region_2d_fp_rate)))), pow(10, math.ceil(math.log10(np.max(region_2d_fp_rate))))])
        
#ax.yaxis.set_major_formatter(tkr.PercentFormatter(decimals=2))




plt.xlabel("Training iterations")
plt.ylabel("False positives rate [%]")
plt.legend()
plt.savefig('false_positives_vs_training_iterations.pdf')

# %%
fig = plt.plot(np.log2((ln_df["trainingIterations"]/100)).astype(int), ln_df["fn_rate"],marker="o", label='Latnav')
plt.plot(np.log2((ann_df["trainingIterations"]/100)).astype(int), ann_df["fn_rate"],marker="o", label="ANN")
plt.plot(np.log2((gauss_df["trainingIterations"]/100)).astype(int), gauss_df["fn_rate"],marker="o", label="Gaussian blur")
plt.plot(np.log2((fft_df["trainingIterations"]/100)).astype(int), fft_df["fn_rate"],marker="o", label="FFT")

plt.grid(visible=True, which='major', color='0.6')
plt.grid(visible=True, which='minor', color='0.8')
#plt.yscale('log')
ax = plt.gca()
plt.tick_params(axis='y', which='minor')

#plt.style.use('classic')
#region_2d_trainIterations=np.array(region_trainIterations)
#region_2d_fp_rate=np.array(region_fp_rate)
#ax.set_ylim([pow(10, math.floor(math.log10(np.min(region_2d_fp_rate)))), pow(10, math.ceil(math.log10(np.max(region_2d_fp_rate))))])
ax.yaxis.set_major_formatter(tkr.PercentFormatter(decimals=0))
ax.yaxis.set_minor_locator(tkr.AutoMinorLocator(4))

#ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(4))
ax.tick_params(axis='y', which='minor', bottom=False)
#plt.gcf().subplots_adjust(left=0.2)
ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x,pos: ('{:d}'.format(int(pow(2, x))*100))))
        

plt.xlabel("Training iterations")
plt.ylabel("Bit-true false negatives rate [%]")
plt.legend(
    #loc='upper right'
)
plt.savefig('false_negatives_vs_training_iterations.pdf')
