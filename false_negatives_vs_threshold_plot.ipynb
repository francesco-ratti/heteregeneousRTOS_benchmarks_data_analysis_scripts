# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

# %%
df=pd.read_csv("ln_thresh.csv", delimiter=";")

# %%
df.head()
# Out:
#    Unnamed: 0  name  regions  trainingIterations  threshold   fn_rate
# 0           0   NaN       16              102400   0.000000  16137965
# 1           1   NaN       16              102400   0.001000   7439100
# 2           2   NaN       16              102400   0.001283   7358760
# 3           3   NaN       16              102400   0.001646   7108963
# 4           4   NaN       16              102400   0.002111   6765625

# %%
df.dropna(axis=1, inplace=True)

# %% [raw]
# print(df)

# %%
            fig = plt.plot(df["threshold"], df["fn_rate"])
            plt.grid(visible=True, which='major', color='0.6')
            plt.grid(visible=True, which='minor', color='0.8')

            plt.yscale('log')
            plt.xscale('log')
            ax=plt.gca()
            # #ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos: ('{:d}%'.format(int(x)))))

            plt.tick_params(axis='y', which='minor')
            plt.tick_params(axis='x', which='minor')


            plt.xlabel("Accepted relative error threshold [%]")
            plt.ylabel("False negatives rate [%]")
# Out:
# Text(0, 0.5, 'False negatives rate [%]')

# %%
            fig = plt.plot(df["threshold"], df["fn_rate"])
            plt.grid(visible=True, which='major', color='0.6')
            plt.grid(visible=True, which='minor', color='0.8')
            ax=plt.gca()            
            ax.xaxis.set_major_formatter(tkr.PercentFormatter(decimals=0))
            ax.yaxis.set_major_formatter(tkr.FuncFormatter(lambda x,pos: ('{:d}%'.format(int(x)))))

            #ax.set_xscale(scl.SymmetricalLogScale(axis.XAxis, base=2))
            plt.tick_params(axis='y', which='minor')
            plt.tick_params(axis='x', which='minor')
            #ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())
            #ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos: ('{:d}%'.format(int(x)))))
            #ax.yaxis.set_minor_formatter(ticker.LogFormatter(10, labelOnlyBase=False, minor_thresholds=(np.inf, np.inf)))
            
            plt.xlabel("Accepted relative error threshold [%]")
            plt.ylabel("False negatives rate [%]")
            
            #ax.xaxis.set_major_formatter(ticker.ScalarFormatter())

            plt.show()
